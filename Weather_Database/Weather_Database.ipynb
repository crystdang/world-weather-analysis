# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 741

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=877660ad03b7399dce36c1836b27e0b0

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_descrip = city_weather["weather"][0]["description"]
        # discovered in https://openweathermap.org/current#data: weather key encloses the many values into one by square brackets, 
        # so the first row must be indicated to retrieve the "description"
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_descrip})
    
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | codrington
# Processing Record 2 of Set 1 | east london
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | cermik
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | saint stephen
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | ilulissat
# Processing Record 9 of Set 1 | tipitapa
# Processing Record 10 of Set 1 | graaff-reinet
# Processing Record 11 of Set 1 | brae
# Processing Record 12 of Set 1 | sao filipe
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | yumen
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | caravelas
# Processing Record 19 of Set 1 | port blair
# Processing Record 20 of Set 1 | handan
# Processing Record 21 of Set 1 | aksu
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | esperance
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | valvedditturai
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | batagay-alyta
# Processing Record 32 of Set 1 | takestan
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | luderitz
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | novikovo
# Processing Record 37 of Set 1 | espanola
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | leningradskiy
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | labuhan
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | challans
# Processing Record 47 of Set 1 | north bend
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | tabas
# Processing Record 1 of Set 2 | dunedin
# Processing Record 2 of Set 2 | the valley
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | innisfail
# Processing Record 5 of Set 2 | hofn
# Processing Record 6 of Set 2 | south lake tahoe
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | kenosha
# Processing Record 10 of Set 2 | katherine
# Processing Record 11 of Set 2 | chara
# Processing Record 12 of Set 2 | kavieng
# Processing Record 13 of Set 2 | uvira
# Processing Record 14 of Set 2 | ponta do sol
# Processing Record 15 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 2 | inhambane
# Processing Record 17 of Set 2 | matveyevka
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | ahipara
# Processing Record 20 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 2 | kita
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | hasaki
# Processing Record 24 of Set 2 | vila velha
# Processing Record 25 of Set 2 | grand gaube
# Processing Record 26 of Set 2 | mariental
# Processing Record 27 of Set 2 | chapais
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | shelburne
# Processing Record 30 of Set 2 | araucaria
# Processing Record 31 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 2 | fort frances
# Processing Record 33 of Set 2 | sitka
# Processing Record 34 of Set 2 | haines junction
# Processing Record 35 of Set 2 | vanimo
# Processing Record 36 of Set 2 | dasoguz
# Processing Record 37 of Set 2 | sao borja
# Processing Record 38 of Set 2 | ratnagiri
# Processing Record 39 of Set 2 | hede
# Processing Record 40 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | karratha
# Processing Record 43 of Set 2 | saint-pierre
# Processing Record 44 of Set 2 | dikson
# Processing Record 45 of Set 2 | khandyga
# Processing Record 46 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 2 | hobart
# Processing Record 48 of Set 2 | isangel
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | uray
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | barghat
# Processing Record 4 of Set 3 | sorong
# Processing Record 5 of Set 3 | krasnyy chikoy
# Processing Record 6 of Set 3 | bangassou
# Processing Record 7 of Set 3 | sekoma
# Processing Record 8 of Set 3 | hualmay
# Processing Record 9 of Set 3 | scarborough
# Processing Record 10 of Set 3 | bambanglipuro
# Processing Record 11 of Set 3 | sobolevo
# Processing Record 12 of Set 3 | marshall
# Processing Record 13 of Set 3 | husavik
# Processing Record 14 of Set 3 | san sebastian
# Processing Record 15 of Set 3 | severo-kurilsk
# Processing Record 16 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 3 | cowra
# Processing Record 18 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 19 of Set 3 | makakilo city
# Processing Record 20 of Set 3 | mount gambier
# Processing Record 21 of Set 3 | puerto cortes
# City not found. Skipping...
# Processing Record 22 of Set 3 | krasnoselkup
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | chuy
# Processing Record 25 of Set 3 | port lincoln
# Processing Record 26 of Set 3 | minab
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | ostrovnoy
# Processing Record 29 of Set 3 | christchurch
# Processing Record 30 of Set 3 | salalah
# Processing Record 31 of Set 3 | mantua
# Processing Record 32 of Set 3 | olenegorsk
# Processing Record 33 of Set 3 | maarianhamina
# Processing Record 34 of Set 3 | beringovskiy
# Processing Record 35 of Set 3 | fort nelson
# Processing Record 36 of Set 3 | lorengau
# Processing Record 37 of Set 3 | darnah
# Processing Record 38 of Set 3 | valparaiso
# Processing Record 39 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 3 | faanui
# Processing Record 41 of Set 3 | pindi bhattian
# Processing Record 42 of Set 3 | coronado
# Processing Record 43 of Set 3 | atar
# Processing Record 44 of Set 3 | lulea
# Processing Record 45 of Set 3 | hithadhoo
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | kachug
# Processing Record 48 of Set 3 | santiago del estero
# Processing Record 49 of Set 3 | srednekolymsk
# Processing Record 50 of Set 3 | george
# Processing Record 1 of Set 4 | lethbridge
# Processing Record 2 of Set 4 | sidney
# Processing Record 3 of Set 4 | tazovskiy
# Processing Record 4 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 4 | avarua
# Processing Record 6 of Set 4 | talaya
# Processing Record 7 of Set 4 | nouadhibou
# Processing Record 8 of Set 4 | dandong
# Processing Record 9 of Set 4 | thompson
# Processing Record 10 of Set 4 | teguldet
# Processing Record 11 of Set 4 | turukhansk
# Processing Record 12 of Set 4 | huilong
# Processing Record 13 of Set 4 | ulaangom
# Processing Record 14 of Set 4 | norman wells
# Processing Record 15 of Set 4 | talnakh
# Processing Record 16 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 4 | port hardy
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | paamiut
# Processing Record 20 of Set 4 | castro
# Processing Record 21 of Set 4 | maragogi
# Processing Record 22 of Set 4 | acapulco
# Processing Record 23 of Set 4 | saint-philippe
# Processing Record 24 of Set 4 | nouakchott
# Processing Record 25 of Set 4 | katsuura
# Processing Record 26 of Set 4 | provideniya
# Processing Record 27 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 4 | chlorakas
# Processing Record 29 of Set 4 | aklavik
# Processing Record 30 of Set 4 | kieta
# Processing Record 31 of Set 4 | bosaso
# Processing Record 32 of Set 4 | saint paul
# Processing Record 33 of Set 4 | vila franca do campo
# Processing Record 34 of Set 4 | xining
# Processing Record 35 of Set 4 | mocuba
# Processing Record 36 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 4 | samana
# Processing Record 39 of Set 4 | lompoc
# Processing Record 40 of Set 4 | tommot
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | ghanzi
# Processing Record 43 of Set 4 | clyde river
# Processing Record 44 of Set 4 | ixtapa
# Processing Record 45 of Set 4 | vao
# Processing Record 46 of Set 4 | byron bay
# Processing Record 47 of Set 4 | san policarpo
# Processing Record 48 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 4 | port-gentil
# Processing Record 50 of Set 4 | palmer
# Processing Record 1 of Set 5 | pontes e lacerda
# Processing Record 2 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 3 of Set 5 | cayenne
# Processing Record 4 of Set 5 | kahului
# Processing Record 5 of Set 5 | jurado
# Processing Record 6 of Set 5 | port elizabeth
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5 | avera
# Processing Record 9 of Set 5 | georgetown
# Processing Record 10 of Set 5 | yerbogachen
# Processing Record 11 of Set 5 | loubomo
# Processing Record 12 of Set 5 | burnie
# Processing Record 13 of Set 5 | shakawe
# Processing Record 14 of Set 5 | bud
# Processing Record 15 of Set 5 | zilair
# Processing Record 16 of Set 5 | saint-augustin
# Processing Record 17 of Set 5 | torit
# Processing Record 18 of Set 5 | la cruz
# Processing Record 19 of Set 5 | narsaq
# Processing Record 20 of Set 5 | asau
# Processing Record 21 of Set 5 | banon
# Processing Record 22 of Set 5 | rio gallegos
# Processing Record 23 of Set 5 | nyagan
# Processing Record 24 of Set 5 | khani
# Processing Record 25 of Set 5 | kailua
# Processing Record 26 of Set 5 | ondangwa
# Processing Record 27 of Set 5 | severnoye
# Processing Record 28 of Set 5 | thayetmyo
# Processing Record 29 of Set 5 | souillac
# Processing Record 30 of Set 5 | port augusta
# Processing Record 31 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 5 | zhigansk
# Processing Record 33 of Set 5 | bosobolo
# Processing Record 34 of Set 5 | huarmey
# Processing Record 35 of Set 5 | sterling
# Processing Record 36 of Set 5 | senador pompeu
# Processing Record 37 of Set 5 | mocajuba
# Processing Record 38 of Set 5 | bontoc
# Processing Record 39 of Set 5 | ancud
# Processing Record 40 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 5 | taseyevo
# Processing Record 42 of Set 5 | moyale
# Processing Record 43 of Set 5 | ngunguru
# Processing Record 44 of Set 5 | waddan
# Processing Record 45 of Set 5 | nikolayevsk-na-amure
# Processing Record 46 of Set 5 | pueblo bello
# Processing Record 47 of Set 5 | abha
# Processing Record 48 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 5 | venice
# Processing Record 50 of Set 5 | falmouth
# Processing Record 1 of Set 6 | aleksandro-nevskiy
# Processing Record 2 of Set 6 | cherskiy
# Processing Record 3 of Set 6 | okhotsk
# Processing Record 4 of Set 6 | viedma
# Processing Record 5 of Set 6 | evensk
# Processing Record 6 of Set 6 | yongan
# Processing Record 7 of Set 6 | bathsheba
# Processing Record 8 of Set 6 | tuatapere
# Processing Record 9 of Set 6 | west richland
# Processing Record 10 of Set 6 | spornoye
# Processing Record 11 of Set 6 | porto velho
# Processing Record 12 of Set 6 | bambous virieux
# Processing Record 13 of Set 6 | bethel
# Processing Record 14 of Set 6 | santa rosa
# Processing Record 15 of Set 6 | touros
# Processing Record 16 of Set 6 | kuna
# Processing Record 17 of Set 6 | upernavik
# Processing Record 18 of Set 6 | alibag
# Processing Record 19 of Set 6 | vrangel
# Processing Record 20 of Set 6 | amherst
# Processing Record 21 of Set 6 | saskylakh
# Processing Record 22 of Set 6 | correntina
# Processing Record 23 of Set 6 | vestmannaeyjar
# Processing Record 24 of Set 6 | pangnirtung
# Processing Record 25 of Set 6 | aberystwyth
# Processing Record 26 of Set 6 | velingara
# Processing Record 27 of Set 6 | aykhal
# Processing Record 28 of Set 6 | volnovakha
# Processing Record 29 of Set 6 | marsh harbour
# Processing Record 30 of Set 6 | xiongyue
# Processing Record 31 of Set 6 | victor harbor
# Processing Record 32 of Set 6 | half moon bay
# Processing Record 33 of Set 6 | puerto escondido
# Processing Record 34 of Set 6 | zutphen
# Processing Record 35 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 6 | faya
# Processing Record 37 of Set 6 | lagoa
# Processing Record 38 of Set 6 | nikolskoye
# Processing Record 39 of Set 6 | kruisfontein
# Processing Record 40 of Set 6 | griffith
# Processing Record 41 of Set 6 | bantou
# Processing Record 42 of Set 6 | machinga
# Processing Record 43 of Set 6 | oksbol
# Processing Record 44 of Set 6 | nantucket
# Processing Record 45 of Set 6 | mahebourg
# Processing Record 46 of Set 6 | the pas
# Processing Record 47 of Set 6 | bria
# Processing Record 48 of Set 6 | turayf
# Processing Record 49 of Set 6 | namibe
# Processing Record 50 of Set 6 | panama city
# Processing Record 1 of Set 7 | saint-denis
# Processing Record 2 of Set 7 | sao joao da barra
# Processing Record 3 of Set 7 | uhlove
# Processing Record 4 of Set 7 | nanortalik
# Processing Record 5 of Set 7 | bilma
# Processing Record 6 of Set 7 | semiletka
# Processing Record 7 of Set 7 | pacific grove
# Processing Record 8 of Set 7 | yamada
# Processing Record 9 of Set 7 | salekhard
# Processing Record 10 of Set 7 | marrakesh
# Processing Record 11 of Set 7 | sur
# Processing Record 12 of Set 7 | bintulu
# Processing Record 13 of Set 7 | omboue
# Processing Record 14 of Set 7 | natitingou
# Processing Record 15 of Set 7 | orgun
# City not found. Skipping...
# Processing Record 16 of Set 7 | portales
# Processing Record 17 of Set 7 | guerrero negro
# Processing Record 18 of Set 7 | carutapera
# Processing Record 19 of Set 7 | victoria
# Processing Record 20 of Set 7 | wajid
# Processing Record 21 of Set 7 | baykit
# Processing Record 22 of Set 7 | amapa
# Processing Record 23 of Set 7 | taoudenni
# Processing Record 24 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 7 | khrustalnyy
# City not found. Skipping...
# Processing Record 26 of Set 7 | sisimiut
# Processing Record 27 of Set 7 | arlit
# Processing Record 28 of Set 7 | mackay
# Processing Record 29 of Set 7 | aneho
# Processing Record 30 of Set 7 | kavaratti
# Processing Record 31 of Set 7 | matara
# Processing Record 32 of Set 7 | riyadh
# Processing Record 33 of Set 7 | mareeba
# Processing Record 34 of Set 7 | bastia
# Processing Record 35 of Set 7 | barranca
# Processing Record 36 of Set 7 | santa maria
# Processing Record 37 of Set 7 | taldan
# Processing Record 38 of Set 7 | xuddur
# Processing Record 39 of Set 7 | san luis
# Processing Record 40 of Set 7 | fukue
# Processing Record 41 of Set 7 | chelno-vershiny
# Processing Record 42 of Set 7 | fayaoue
# Processing Record 43 of Set 7 | nerchinskiy zavod
# Processing Record 44 of Set 7 | eureka
# Processing Record 45 of Set 7 | black river
# Processing Record 46 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 7 | ust-kulom
# Processing Record 48 of Set 7 | tocopilla
# Processing Record 49 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 7 | saint-louis
# Processing Record 1 of Set 8 | nelson bay
# Processing Record 2 of Set 8 | san patricio
# Processing Record 3 of Set 8 | hobyo
# Processing Record 4 of Set 8 | laguna
# Processing Record 5 of Set 8 | cabedelo
# Processing Record 6 of Set 8 | tilichiki
# Processing Record 7 of Set 8 | ust-nera
# Processing Record 8 of Set 8 | kodiak
# Processing Record 9 of Set 8 | los llanos de aridane
# Processing Record 10 of Set 8 | bremerton
# Processing Record 11 of Set 8 | falakata
# Processing Record 12 of Set 8 | perivolion
# Processing Record 13 of Set 8 | pisco
# Processing Record 14 of Set 8 | keelung
# Processing Record 15 of Set 8 | livingston
# Processing Record 16 of Set 8 | angoche
# Processing Record 17 of Set 8 | alihe
# Processing Record 18 of Set 8 | mancio lima
# Processing Record 19 of Set 8 | tura
# Processing Record 20 of Set 8 | vastervik
# City not found. Skipping...
# Processing Record 21 of Set 8 | bonavista
# Processing Record 22 of Set 8 | dingle
# Processing Record 23 of Set 8 | valley city
# Processing Record 24 of Set 8 | sandwick
# Processing Record 25 of Set 8 | saint anthony
# Processing Record 26 of Set 8 | oistins
# Processing Record 27 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 28 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 29 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 8 | akureyri
# Processing Record 31 of Set 8 | bilibino
# Processing Record 32 of Set 8 | coquimbo
# Processing Record 33 of Set 8 | phumi samraong
# City not found. Skipping...
# Processing Record 34 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 8 | fortuna
# Processing Record 36 of Set 8 | kirakira
# Processing Record 37 of Set 8 | hay river
# Processing Record 38 of Set 8 | porto novo
# Processing Record 39 of Set 8 | wangdiphodrang
# City not found. Skipping...
# Processing Record 40 of Set 8 | tessalit
# Processing Record 41 of Set 8 | olinda
# Processing Record 42 of Set 8 | pismo beach
# Processing Record 43 of Set 8 | tezu
# Processing Record 44 of Set 8 | necochea
# Processing Record 45 of Set 8 | tukrah
# Processing Record 46 of Set 8 | nobres
# Processing Record 47 of Set 8 | kingsland
# Processing Record 48 of Set 8 | phek
# Processing Record 49 of Set 8 | merauke
# Processing Record 50 of Set 8 | oktyabrskiy
# Processing Record 1 of Set 9 | xingyi
# Processing Record 2 of Set 9 | moerai
# Processing Record 3 of Set 9 | agadez
# Processing Record 4 of Set 9 | razole
# Processing Record 5 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 9 | lata
# Processing Record 7 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 8 of Set 9 | saldanha
# Processing Record 9 of Set 9 | alofi
# Processing Record 10 of Set 9 | nabire
# Processing Record 11 of Set 9 | pokhara
# Processing Record 12 of Set 9 | verkhoyansk
# Processing Record 13 of Set 9 | wad madani
# Processing Record 14 of Set 9 | hami
# Processing Record 15 of Set 9 | rafai
# Processing Record 16 of Set 9 | porto belo
# Processing Record 17 of Set 9 | kaitangata
# Processing Record 18 of Set 9 | baran
# Processing Record 19 of Set 9 | ialibu
# Processing Record 20 of Set 9 | ewa beach
# Processing Record 21 of Set 9 | paranavai
# Processing Record 22 of Set 9 | cam ranh
# Processing Record 23 of Set 9 | coahuayana
# Processing Record 24 of Set 9 | gambela
# Processing Record 25 of Set 9 | bubaque
# Processing Record 26 of Set 9 | kamenka
# Processing Record 27 of Set 9 | iki-burul
# Processing Record 28 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 9 | san ramon
# Processing Record 30 of Set 9 | cordoba
# Processing Record 31 of Set 9 | maniitsoq
# Processing Record 32 of Set 9 | talara
# Processing Record 33 of Set 9 | klaksvik
# Processing Record 34 of Set 9 | wasilla
# Processing Record 35 of Set 9 | orlik
# Processing Record 36 of Set 9 | antalaha
# Processing Record 37 of Set 9 | kadaya
# Processing Record 38 of Set 9 | kalangala
# Processing Record 39 of Set 9 | usinsk
# Processing Record 40 of Set 9 | vardo
# Processing Record 41 of Set 9 | skelleftea
# Processing Record 42 of Set 9 | nsanje
# Processing Record 43 of Set 9 | port macquarie
# Processing Record 44 of Set 9 | krasnouralsk
# Processing Record 45 of Set 9 | kawalu
# Processing Record 46 of Set 9 | birjand
# Processing Record 47 of Set 9 | lavrentiya
# Processing Record 48 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 49 of Set 9 | rawatbhata
# Processing Record 50 of Set 9 | havre-saint-pierre
# Processing Record 1 of Set 10 | flin flon
# Processing Record 2 of Set 10 | la crosse
# Processing Record 3 of Set 10 | westport
# Processing Record 4 of Set 10 | staryy nadym
# Processing Record 5 of Set 10 | mastic beach
# Processing Record 6 of Set 10 | iqaluit
# Processing Record 7 of Set 10 | nelson
# Processing Record 8 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 10 | santa lucia
# Processing Record 11 of Set 10 | maine-soroa
# Processing Record 12 of Set 10 | jiayuguan
# Processing Record 13 of Set 10 | imeni babushkina
# Processing Record 14 of Set 10 | mombetsu
# Processing Record 15 of Set 10 | ugoofaaru
# Processing Record 16 of Set 10 | margate
# Processing Record 17 of Set 10 | alekseyevsk
# Processing Record 18 of Set 10 | ahuimanu
# Processing Record 19 of Set 10 | okoneshnikovo
# Processing Record 20 of Set 10 | ginda
# Processing Record 21 of Set 10 | kedougou
# Processing Record 22 of Set 10 | port hedland
# Processing Record 23 of Set 10 | alyangula
# Processing Record 24 of Set 10 | bagdarin
# Processing Record 25 of Set 10 | timbiqui
# Processing Record 26 of Set 10 | blyth
# Processing Record 27 of Set 10 | opuwo
# Processing Record 28 of Set 10 | roald
# Processing Record 29 of Set 10 | okha
# Processing Record 30 of Set 10 | kirkwood
# Processing Record 31 of Set 10 | yakeshi
# Processing Record 32 of Set 10 | dourbali
# Processing Record 33 of Set 10 | taltal
# Processing Record 34 of Set 10 | marsaxlokk
# Processing Record 35 of Set 10 | eresos
# Processing Record 36 of Set 10 | geraldton
# Processing Record 37 of Set 10 | lima
# Processing Record 38 of Set 10 | maamba
# Processing Record 39 of Set 10 | kiama
# Processing Record 40 of Set 10 | zalantun
# Processing Record 41 of Set 10 | toktogul
# Processing Record 42 of Set 10 | vulcan
# Processing Record 43 of Set 10 | tranas
# Processing Record 44 of Set 10 | islamkot
# Processing Record 45 of Set 10 | bengkulu
# Processing Record 46 of Set 10 | buala
# Processing Record 47 of Set 10 | lakhnadon
# Processing Record 48 of Set 10 | pafos
# Processing Record 49 of Set 10 | ambilobe
# Processing Record 50 of Set 10 | najran
# Processing Record 1 of Set 11 | jumla
# Processing Record 2 of Set 11 | praia da vitoria
# Processing Record 3 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 11 | olafsvik
# Processing Record 5 of Set 11 | kloulklubed
# Processing Record 6 of Set 11 | pevek
# Processing Record 7 of Set 11 | kirksville
# Processing Record 8 of Set 11 | kashi
# Processing Record 9 of Set 11 | acajutla
# Processing Record 10 of Set 11 | purpe
# Processing Record 11 of Set 11 | sakakah
# Processing Record 12 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 13 of Set 11 | verkhnevilyuysk
# Processing Record 14 of Set 11 | roblin
# Processing Record 15 of Set 11 | sankrail
# Processing Record 16 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 11 | sola
# Processing Record 18 of Set 11 | mungaa
# Processing Record 19 of Set 11 | sukhumi
# Processing Record 20 of Set 11 | gawler
# Processing Record 21 of Set 11 | remetea mare
# Processing Record 22 of Set 11 | nam dinh
# Processing Record 23 of Set 11 | anqing
# Processing Record 24 of Set 11 | braunau
# Processing Record 25 of Set 11 | chifeng
# Processing Record 26 of Set 11 | seoul
# Processing Record 27 of Set 11 | benicarlo
# Processing Record 28 of Set 11 | grindavik
# Processing Record 29 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 11 | nieuw amsterdam
# Processing Record 31 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 32 of Set 11 | mana
# Processing Record 33 of Set 11 | osoyoos
# Processing Record 34 of Set 11 | te anau
# Processing Record 35 of Set 11 | pangody
# Processing Record 36 of Set 11 | mehamn
# Processing Record 37 of Set 11 | panorama
# Processing Record 38 of Set 11 | muana
# Processing Record 39 of Set 11 | pathein
# Processing Record 40 of Set 11 | poum
# Processing Record 41 of Set 11 | manokwari
# Processing Record 42 of Set 11 | sanok
# Processing Record 43 of Set 11 | leshukonskoye
# Processing Record 44 of Set 11 | puyang
# Processing Record 45 of Set 11 | maslovare
# Processing Record 46 of Set 11 | moose factory
# Processing Record 47 of Set 11 | yar-sale
# Processing Record 48 of Set 11 | huntsville
# Processing Record 49 of Set 11 | baijiantan
# Processing Record 50 of Set 11 | altay
# Processing Record 1 of Set 12 | hirara
# Processing Record 2 of Set 12 | camacha
# Processing Record 3 of Set 12 | sabha
# Processing Record 4 of Set 12 | biloela
# Processing Record 5 of Set 12 | lakeway
# Processing Record 6 of Set 12 | saint-leu
# Processing Record 7 of Set 12 | tarko-sale
# Processing Record 8 of Set 12 | jibuti
# Processing Record 9 of Set 12 | kasempa
# Processing Record 10 of Set 12 | atambua
# Processing Record 11 of Set 12 | mildura
# Processing Record 12 of Set 12 | russell
# Processing Record 13 of Set 12 | mitsamiouli
# Processing Record 14 of Set 12 | hoyerswerda
# Processing Record 15 of Set 12 | yaan
# Processing Record 16 of Set 12 | semirom
# Processing Record 17 of Set 12 | nagato
# Processing Record 18 of Set 12 | dinar
# Processing Record 19 of Set 12 | yubari
# Processing Record 20 of Set 12 | meaford
# Processing Record 21 of Set 12 | san quintin
# Processing Record 22 of Set 12 | hays
# Processing Record 23 of Set 12 | san cristobal
# Processing Record 24 of Set 12 | coihaique
# Processing Record 25 of Set 12 | togur
# Processing Record 26 of Set 12 | leek
# Processing Record 27 of Set 12 | blagoyevo
# Processing Record 28 of Set 12 | eydhafushi
# Processing Record 29 of Set 12 | harlingen
# Processing Record 30 of Set 12 | providencia
# Processing Record 31 of Set 12 | college
# Processing Record 32 of Set 12 | port keats
# Processing Record 33 of Set 12 | tarabuco
# Processing Record 34 of Set 12 | biak
# Processing Record 35 of Set 12 | beloha
# Processing Record 36 of Set 12 | prince rupert
# Processing Record 37 of Set 12 | flinders
# Processing Record 38 of Set 12 | chumikan
# Processing Record 39 of Set 12 | ramshir
# Processing Record 40 of Set 12 | hambantota
# Processing Record 41 of Set 12 | yuli
# Processing Record 42 of Set 12 | aldan
# Processing Record 43 of Set 12 | smithers
# Processing Record 44 of Set 12 | impfondo
# Processing Record 45 of Set 12 | dakoro
# Processing Record 46 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 47 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 48 of Set 12 | hashtrud
# Processing Record 49 of Set 12 | tocache
# Processing Record 50 of Set 12 | mondeville
# Processing Record 1 of Set 13 | myaundzha
# Processing Record 2 of Set 13 | mezen
# Processing Record 3 of Set 13 | chipinge
# Processing Record 4 of Set 13 | berlevag
# Processing Record 5 of Set 13 | port lavaca
# Processing Record 6 of Set 13 | rorvik
# Processing Record 7 of Set 13 | severnyy
# Processing Record 8 of Set 13 | nizwa
# Processing Record 9 of Set 13 | lakki marwat
# Processing Record 10 of Set 13 | wewak
# Processing Record 11 of Set 13 | kemijarvi
# Processing Record 12 of Set 13 | salinas
# Processing Record 13 of Set 13 | tautira
# Processing Record 14 of Set 13 | yambio
# Processing Record 15 of Set 13 | sala
# Processing Record 16 of Set 13 | gadung
# Processing Record 17 of Set 13 | yenagoa
# Processing Record 18 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 19 of Set 13 | novobirilyussy
# Processing Record 20 of Set 13 | moron
# Processing Record 21 of Set 13 | kutum
# Processing Record 22 of Set 13 | ketchikan
# Processing Record 23 of Set 13 | aguie
# Processing Record 24 of Set 13 | lufilufi
# Processing Record 25 of Set 13 | dali
# Processing Record 26 of Set 13 | mbandaka
# Processing Record 27 of Set 13 | ayan
# Processing Record 28 of Set 13 | inirida
# Processing Record 29 of Set 13 | fredericton
# Processing Record 30 of Set 13 | quthing
# Processing Record 31 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 13 | camana
# Processing Record 33 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 34 of Set 13 | samarai
# Processing Record 35 of Set 13 | constitucion
# Processing Record 36 of Set 13 | aguia branca
# Processing Record 37 of Set 13 | mersing
# Processing Record 38 of Set 13 | bermejillo
# Processing Record 39 of Set 13 | skole
# Processing Record 40 of Set 13 | emerald
# Processing Record 41 of Set 13 | keetmanshoop
# Processing Record 42 of Set 13 | ouegoa
# Processing Record 43 of Set 13 | greenwood
# Processing Record 44 of Set 13 | velasco ibarra
# Processing Record 45 of Set 13 | miri
# Processing Record 46 of Set 13 | airai
# Processing Record 47 of Set 13 | meadow lake
# Processing Record 48 of Set 13 | mount isa
# Processing Record 49 of Set 13 | broome
# Processing Record 50 of Set 13 | carbondale
# Processing Record 1 of Set 14 | wamba
# Processing Record 2 of Set 14 | thunder bay
# Processing Record 3 of Set 14 | tawzar
# City not found. Skipping...
# Processing Record 4 of Set 14 | roswell
# Processing Record 5 of Set 14 | dien bien
# City not found. Skipping...
# Processing Record 6 of Set 14 | kampene
# Processing Record 7 of Set 14 | muros
# Processing Record 8 of Set 14 | kokopo
# Processing Record 9 of Set 14 | havelock
# Processing Record 10 of Set 14 | parubcan
# City not found. Skipping...
# Processing Record 11 of Set 14 | ghotki
# Processing Record 12 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 13 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 14 of Set 14 | salinopolis
# Processing Record 15 of Set 14 | bandarbeyla
# Processing Record 16 of Set 14 | ikwiriri
# Processing Record 17 of Set 14 | senekal
# Processing Record 18 of Set 14 | obidos
# Processing Record 19 of Set 14 | kushima
# Processing Record 20 of Set 14 | san carlos de bariloche
# Processing Record 21 of Set 14 | kununurra
# Processing Record 22 of Set 14 | namatanai
# Processing Record 23 of Set 14 | siniscola
# Processing Record 24 of Set 14 | luancheng
# Processing Record 25 of Set 14 | sorland
# Processing Record 26 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 27 of Set 14 | sidi ali
# Processing Record 28 of Set 14 | neiafu
# Processing Record 29 of Set 14 | anloga
# Processing Record 30 of Set 14 | skegness
# Processing Record 31 of Set 14 | korla
# Processing Record 32 of Set 14 | cehegin
# Processing Record 33 of Set 14 | pyaozerskiy
# Processing Record 34 of Set 14 | zhangye
# Processing Record 35 of Set 14 | stornoway
# Processing Record 36 of Set 14 | sarangani
# Processing Record 37 of Set 14 | rodrigues alves
# Processing Record 38 of Set 14 | jahrom
# City not found. Skipping...
# Processing Record 39 of Set 14 | tiksi
# Processing Record 40 of Set 14 | kahta
# Processing Record 41 of Set 14 | putnam
# Processing Record 42 of Set 14 | antsohihy
# Processing Record 43 of Set 14 | skiros
# City not found. Skipping...
# Processing Record 44 of Set 14 | banda aceh
# Processing Record 45 of Set 14 | la ronge
# Processing Record 46 of Set 14 | kardla
# Processing Record 47 of Set 14 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 48 of Set 14 | villanueva de la serena
# Processing Record 49 of Set 14 | ndele
# Processing Record 50 of Set 14 | la plata
# Processing Record 1 of Set 15 | vostok
# Processing Record 2 of Set 15 | consett
# Processing Record 3 of Set 15 | plettenberg bay
# Processing Record 4 of Set 15 | norrtalje
# Processing Record 5 of Set 15 | qui nhon
# Processing Record 6 of Set 15 | casablanca
# Processing Record 7 of Set 15 | koksovyy
# Processing Record 8 of Set 15 | arkhangelsk
# Processing Record 9 of Set 15 | lashio
# Processing Record 10 of Set 15 | killybegs
# Processing Record 11 of Set 15 | whitecourt
# Processing Record 12 of Set 15 | killam
# Processing Record 13 of Set 15 | klatovy
# Processing Record 14 of Set 15 | lengshuijiang
# Processing Record 15 of Set 15 | bereda
# Processing Record 16 of Set 15 | henties bay
# Processing Record 17 of Set 15 | puerto el triunfo
# Processing Record 18 of Set 15 | pinar del rio
# Processing Record 19 of Set 15 | ekhabi
# Processing Record 20 of Set 15 | ulladulla
# Processing Record 21 of Set 15 | tiznit
# Processing Record 22 of Set 15 | goderich
# Processing Record 23 of Set 15 | ca mau
# Processing Record 24 of Set 15 | victoria falls
# Processing Record 25 of Set 15 | dudinka
# Processing Record 26 of Set 15 | nadvoitsy
# Processing Record 27 of Set 15 | moirang
# Processing Record 28 of Set 15 | slonim
# Processing Record 29 of Set 15 | haikou
# Processing Record 30 of Set 15 | svetlogorsk
# Processing Record 31 of Set 15 | lethem
# Processing Record 32 of Set 15 | alamosa
# Processing Record 33 of Set 15 | neman
# Processing Record 34 of Set 15 | marau
# Processing Record 35 of Set 15 | moba
# Processing Record 36 of Set 15 | campos
# Processing Record 37 of Set 15 | sioux lookout
# Processing Record 38 of Set 15 | kalabo
# Processing Record 39 of Set 15 | eyl
# Processing Record 40 of Set 15 | wuchang
# Processing Record 41 of Set 15 | santa barbara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 680

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Codrington -38.2667  141.9667     64.08        83          96
# 1    East London -33.0153   27.9116     63.64        83          84
# 2        Rikitea -23.1203 -134.9692     69.67        61          71
# 3         Cermik  38.1361   39.4493     73.71        40          19
# 4      Busselton -33.6500  115.3333     56.55        72          92
# 5  Saint Stephen  50.3333   -4.9000     55.67        76          20
# 6   Puerto Ayora  -0.7393  -90.3518     65.55        96          60
# 7      Ilulissat  69.2167  -51.1000     26.62        68         100
# 8       Tipitapa  12.1973  -86.0971     80.62        83          40
# 9  Graaff-Reinet -32.2522   24.5308     53.92        93          67
#
#    Wind Speed Country Current Description
# 0       13.04      AU          light rain
# 1       13.13      ZA       broken clouds
# 2       20.24      PF       broken clouds
# 3        1.86      TR          few clouds
# 4       14.12      AU     overcast clouds
# 5        8.05      GB          few clouds
# 6        3.00      EC       broken clouds
# 7        0.00      GL     overcast clouds
# 8        0.00      NI    scattered clouds
# 9        0.94      ZA       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Codrington      AU -38.2667  141.9667     64.08        83          96
# 1    East London      ZA -33.0153   27.9116     63.64        83          84
# 2        Rikitea      PF -23.1203 -134.9692     69.67        61          71
# 3         Cermik      TR  38.1361   39.4493     73.71        40          19
# 4      Busselton      AU -33.6500  115.3333     56.55        72          92
# 5  Saint Stephen      GB  50.3333   -4.9000     55.67        76          20
# 6   Puerto Ayora      EC  -0.7393  -90.3518     65.55        96          60
# 7      Ilulissat      GL  69.2167  -51.1000     26.62        68         100
# 8       Tipitapa      NI  12.1973  -86.0971     80.62        83          40
# 9  Graaff-Reinet      ZA -32.2522   24.5308     53.92        93          67
#
#    Wind Speed Current Description
# 0       13.04          light rain
# 1       13.13       broken clouds
# 2       20.24       broken clouds
# 3        1.86          few clouds
# 4       14.12     overcast clouds
# 5        8.05          few clouds
# 6        3.00       broken clouds
# 7        0.00     overcast clouds
# 8        0.00    scattered clouds
# 9        0.94       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
